# %% [markdown]
# # 34. Find First and Last Position of Element in Sorted Array
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array of integers `nums` sorted in non-decreasing order, find the starting and ending position of a given `target` value.
#
# If the target is not found in the array, return `[-1, -1]`.
#
# You must write an algorithm with `O(log n)` runtime complexity.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [5,7,7,8,8,10]`, `target = 8`
# - Output: `[3, 4]`
#
# **Example 2**
# - Input: `nums = [5,7,7,8,8,10]`, `target = 6`
# - Output: `[-1, -1]`
#
# **Example 3**
# - Input: `nums = []`, `target = 0`
# - Output: `[-1, -1]`
#
# ## Constraints
# - `0 ≤ nums.length ≤ 10^5`
# - `-10^9 ≤ nums[i] ≤ 10^9`
# - `nums` is a non-decreasing array
# - `-10^9 ≤ target ≤ 10^9`

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        
        def firstOccur(nums,target):
            low = 0
            high = len(nums)-1
            start = -1
            while low <= high:
                mid = (low+high)//2
                if nums[mid] == target:
                    start = mid
                    high = mid-1
                elif nums[mid] > target:
                    high = mid-1
                elif nums[mid] < target:
                    low = mid+1
            return start
        
        def lastOccur(nums,target):
            last = -1
            low = 0
            high = len(nums) - 1
            while low <= high:
                mid = (high+low)//2
                if nums[mid] == target:
                    last = mid
                    low = mid + 1
                elif nums[mid] > target:
                    high = mid - 1
                elif nums[mid] < target:
                    low = mid + 1
            return last
        
        return [firstOccur(nums,target), lastOccur(nums,target)]

# %% [markdown]
# # 35. Search Insert Position
#
# ## Difficulty
# Easy
#
# ## Description
# Given a sorted array of distinct integers `nums` and a target value `target`, return the index if the target is found.
#
# If not, return the index where it would be inserted in order.
#
# You must write an algorithm with `O(log n)` runtime complexity.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,3,5,6]`, `target = 5`
# - Output: `2`
#
# **Example 2**
# - Input: `nums = [1,3,5,6]`, `target = 2`
# - Output: `1`
#
# **Example 3**
# - Input: `nums = [1,3,5,6]`, `target = 7`
# - Output: `4`
#
# ## Constraints
# - `1 ≤ nums.length ≤ 10^4`
# - `-10^4 ≤ nums[i] ≤ 10^4`
# - `nums` contains distinct values sorted in ascending order
# - `-10^4 ≤ target ≤ 10^4`

# %%
class Solution:
    def searchInsert(self, nums: List[int], target: int) -> int:
        low = 0
        high = len(nums) - 1
        out  = -1
        while low <= high:
            mid = (high+low)//2

            if nums[mid] == target:
                return mid
            elif nums[mid] > target:
                high = mid - 1
                out = mid
            elif nums[mid] < target:
                low = mid + 1
                out = mid + 1
        if out < 0:
            out = 0
        return out

# %% [markdown]
# # 81. Search in Rotated Sorted Array II
#
# ## Difficulty
# Medium
#
# ## Description
# There is an integer array `nums` sorted in non-decreasing order (not necessarily with distinct values).
#
# Before being passed to your function, `nums` is rotated at an unknown pivot index `k` (`0 ≤ k < nums.length`) such that the resulting array is:
# `[nums[k], nums[k+1], ..., nums[n-1], nums[0], nums[1], ..., nums[k-1]]`.
#
# Given the array `nums` after the rotation and an integer `target`, return `true` if `target` exists in `nums`, otherwise return `false`.
#
# You should minimize the overall number of operations as much as possible.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [2,5,6,0,0,1,2]`, `target = 0`
# - Output: `true`
#
# **Example 2**
# - Input: `nums = [2,5,6,0,0,1,2]`, `target = 3`
# - Output: `false`
#
# ## Constraints
# - `1 ≤ nums.length ≤ 5000`
# - `-10^4 ≤ nums[i] ≤ 10^4`
# - `nums` is guaranteed to be rotated at some pivot
# - `-10^4 ≤ target ≤ 10^4`
#
# ## Follow-up
# - This problem is similar to **Search in Rotated Sorted Array**, but `nums` may contain duplicates. Would this affect the runtime complexity? How and why?

# %%
class Solution:
    def search(self, nums: List[int], target: int) -> bool:
        for i in nums:
            if i == target:
                return True
        else:
            return False

# %% [markdown]
# # 154. Find Minimum in Rotated Sorted Array II
#
# ## Difficulty
# Hard
#
# ## Description
# Suppose an array of length `n` sorted in ascending order is rotated between 1 and `n` times.
#
# For example:
# - `[0,1,4,4,5,6,7]` rotated 4 times becomes `[4,5,6,7,0,1,4]`
# - `[0,1,4,4,5,6,7]` rotated 7 times remains `[0,1,4,4,5,6,7]`
#
# Rotating an array one time means moving the last element to the front.
#
# Given the sorted and rotated array `nums` that may contain duplicates, return the minimum element of this array.
#
# You should minimize the overall number of operations as much as possible.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,3,5]`
# - Output: `1`
#
# **Example 2**
# - Input: `nums = [2,2,2,0,1]`
# - Output: `0`
#
# ## Constraints
# - `n == nums.length`
# - `1 ≤ n ≤ 5000`
# - `-5000 ≤ nums[i] ≤ 5000`
# - `nums` is sorted and rotated between 1 and `n` times
#
# ## Follow-up
# - This problem is similar to **Find Minimum in Rotated Sorted Array**, but `nums` may contain duplicates. Would this affect the runtime complexity? How and why?

# %%
class Solution:
    def findMin(self, nums: List[int]) -> int:
        min_value = float('inf')
        low = 0
        high = len(nums)-1

        while low <= high:
            mid = (low+high)//2
  
            if nums[low] < nums[mid]:
                min_value = min(min_value,nums[low])
                low = mid+1
            elif nums[high] > nums[mid]:
                min_value = min(min_value,nums[mid])
                high = mid-1 
            elif nums[low] == nums[mid]:
                min_value = min(min_value,nums[mid])
                low += 1
            elif nums[high] == nums[mid]:
                min_value = min(min_value,nums[mid])
                high -= 1


        return min_value

# %% [markdown]
# # 153. Find Minimum in Rotated Sorted Array
#
# ## Difficulty
# Medium
#
# ## Description
# Suppose an array of length `n` sorted in ascending order is rotated between 1 and `n` times.
#
# For example:
# - `[0,1,2,4,5,6,7]` rotated 4 times becomes `[4,5,6,7,0,1,2]`
# - `[0,1,2,4,5,6,7]` rotated 7 times remains `[0,1,2,4,5,6,7]`
#
# Rotating an array one time moves the last element to the front.
#
# Given the sorted and rotated array `nums` containing **unique elements**, return the minimum element of this array.
#
# You must write an algorithm that runs in `O(log n)` time.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [3,4,5,1,2]`
# - Output: `1`
#
# **Example 2**
# - Input: `nums = [4,5,6,7,0,1,2]`
# - Output: `0`
#
# **Example 3**
# - Input: `nums = [11,13,15,17]`
# - Output: `11`
#
# ## Constraints
# - `n == nums.length`
# - `1 ≤ n ≤ 5000`
# - `-5000 ≤ nums[i] ≤ 5000`
# - All elements in `nums` are unique
# - `nums` is sorted and rotated between 1 and `n` times

# %%
class Solution:
    def findMin(self, nums: List[int]) -> int:
        min_value = float('inf')

        low = 0
        high = len(nums) -1

        while low <= high:
            mid = (low+high) // 2

            if nums[mid] >= nums[low]:
                min_value = min(min_value, nums[low])
                low = mid+1
            elif nums[mid] <= nums[high]:
                min_value = min(min_value, nums[mid])
                high = mid-1

        return min_value

# %% [markdown]
# # 162. Find Peak Element
#
# ## Difficulty
# Medium
#
# ## Description
# A peak element is an element that is strictly greater than its neighbors.
#
# Given a 0-indexed integer array `nums`, find a peak element and return its index. If the array contains multiple peaks, return the index of any peak.
#
# You may assume that `nums[-1] = nums[n] = -∞`, meaning elements outside the array are considered smaller than any element inside.
#
# You must write an algorithm that runs in `O(log n)` time.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,2,3,1]`
# - Output: `2`
# - Explanation: Element `3` is a peak element.
#
# **Example 2**
# - Input: `nums = [1,2,1,3,5,6,4]`
# - Output: `5`
# - Explanation: Either index `1` (value 2) or index `5` (value 6) is a valid peak.
#
# ## Constraints
# - `1 ≤ nums.length ≤ 1000`
# - `-2^31 ≤ nums[i] ≤ 2^31 - 1`
# - `nums[i] != nums[i + 1]` for all valid `i`

# %% [markdown]
# # Array Duplicates
#
# ## Difficulty
# Easy
#
# ## Description
# Given an array `arr[]` of size `n` containing elements from the range `1` to `n`, where each element appears at most twice, return an array of all integers that appear twice.
#
# The elements can be returned in any order.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = [2, 3, 1, 2, 3]`
# - Output: `[2, 3]`
# - Explanation: 2 and 3 occur more than once in the array.
#
# **Example 2**
# - Input: `arr[] = [3, 1, 2]`
# - Output: `[]`
# - Explanation: No element appears more than once.
#
# ## Constraints
# - `1 ≤ n ≤ 10^6`
# - `1 ≤ arr[i] ≤ n`

# %% [markdown]
# # 540. Single Element in a Sorted Array
#
# ## Difficulty
# Medium
#
# ## Description
# You are given a sorted array `nums` consisting of integers where every element appears exactly twice, except for one element which appears exactly once.
#
# Return the single element that appears only once.
#
# Your solution must run in `O(log n)` time and use `O(1)` extra space.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,1,2,3,3,4,4,8,8]`
# - Output: `2`
#
# **Example 2**
# - Input: `nums = [3,3,7,7,10,11,11]`
# - Output: `10`
#
# ## Constraints
# - `1 ≤ nums.length ≤ 10^5`
# - `0 ≤ nums[i] ≤ 10^5`

# %% [markdown]
# # Kth Smallest Element in the Array Using Constant Space
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array `arr[]` of size `N` containing distinct elements and an integer `K`, find the `K`th smallest element in the array.
#
# The array **cannot be modified**, and the solution must use **constant extra space**.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = {7, 10, 4, 3, 20, 15}`, `K = 3`
# - Output: `7`
# - Explanation: The sorted array is `{3, 4, 7, 10, 15, 20}`. The 3rd smallest element is 7.
#
# **Example 2**
# - Input: `arr[] = {12, 3, 5, 7, 19}`, `K = 2`
# - Output: `5`
#
# ## Constraints
# - All elements in the array are distinct
# - `1 ≤ K ≤ N`
# - The array must not be modified
# - Constant extra space must be used

# %% [markdown]
# # 378. Kth Smallest Element in a Sorted Matrix
#
# ## Difficulty
# Medium
#
# ## Description
# Given an `n x n` matrix where each row and each column is sorted in ascending order, return the `k`th smallest element in the matrix.
#
# Note that it is the `k`th smallest element in the sorted order, not the `k`th distinct element.
#
# You must find a solution with memory complexity better than `O(n^2)`.
#
# ## Examples
#
# **Example 1**
# - Input: `matrix = [[1,5,9],[10,11,13],[12,13,15]]`, `k = 8`
# - Output: `13`
# - Explanation: The sorted elements are `[1,5,9,10,11,12,13,13,15]`. The 8th smallest element is 13.
#
# **Example 2**
# - Input: `matrix = [[-5]]`, `k = 1`
# - Output: `-5`
#
# ## Constraints
# - `n == matrix.length == matrix[i].length`
# - `1 ≤ n ≤ 300`
# - `-10^9 ≤ matrix[i][j] ≤ 10^9`
# - Each row and column of the matrix is sorted in non-decreasing order
# - `1 ≤ k ≤ n^2`
#
# ## Follow-up
# - Can you solve the problem using constant extra space (`O(1)` memory)?
# - Can you solve the problem in `O(n)` time complexity?

# %% [markdown]
# # Maximum Subarray Size Having All Subarrays Sums Less Than or Equal to K
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array `arr[]` of positive integers of size `n` and an integer `k`, find the maximum subarray size such that **all subarrays of that size** have a sum less than or equal to `k`.
#
# If no such subarray size exists, return `-1`.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = [1, 2, 3, 4]`, `k = 8`
# - Output: `2`
# - Explanation:
#   - Size 1 subarrays: sums = 1, 2, 3, 4
#   - Size 2 subarrays: sums = 3, 5, 7
#   - Size 3 subarrays: sums = 6, 9
#   - Size 4 subarrays: sum = 10
#   Maximum size where all subarrays have sum ≤ 8 is 2.
#
# **Example 2**
# - Input: `arr[] = [1, 2, 10, 4]`, `k = 8`
# - Output: `-1`
# - Explanation: Element `10` is greater than `k`, so no valid subarray size exists.
#
# **Example 3**
# - Input: `arr[] = [1, 2, 10, 4]`, `k = 14`
# - Output: `2`
#
# ## Constraints
# - `1 ≤ n ≤ 10^5`
# - `1 ≤ arr[i] ≤ 10^9`
# - `1 ≤ k ≤ 10^18`

# %% [markdown]
# # Aggressive Cows
#
# ## Difficulty
# Medium
#
# ## Description
# You are given an array `stalls[]` containing unique elements that represent the positions of stalls, and an integer `k` representing the number of aggressive cows.
#
# Assign stalls to `k` cows such that the **minimum distance between any two cows is maximized**. Return the maximum possible value of this minimum distance.
#
# ## Examples
#
# **Example 1**
# - Input: `stalls[] = [1, 2, 4, 8, 9]`, `k = 3`
# - Output: `3`
# - Explanation: Cows can be placed at positions 1, 4, and 8. The minimum distance between any two cows is 3.
#
# **Example 2**
# - Input: `stalls[] = [10, 1, 2, 7, 5]`, `k = 3`
# - Output: `4`
# - Explanation: Cows can be placed at positions 1, 5, and 10. The minimum distance between any two cows is 4.
#
# **Example 3**
# - Input: `stalls[] = [2, 12, 11, 3, 26, 7]`, `k = 5`
# - Output: `1`
# - Explanation: With 6 stalls and 5 cows, the maximum possible minimum distance is 1.
#
# ## Constraints
# - `2 ≤ stalls.size() ≤ 10^6`
# - `0 ≤ stalls[i] ≤ 10^8`
# - `2 ≤ k ≤ stalls.size()`

# %% [markdown]
# # 240. Search a 2D Matrix II
#
# ## Difficulty
# Medium
#
# ## Description
# Given an `m x n` integer matrix `matrix` and an integer `target`, write an efficient algorithm to determine whether `target` exists in the matrix.
#
# The matrix has the following properties:
# - Integers in each row are sorted in ascending order from left to right.
# - Integers in each column are sorted in ascending order from top to bottom.
#
# Return `true` if `target` is found in the matrix, otherwise return `false`.
#
# ## Examples
#
# **Example 1**
# - Input:
#   `matrix = [[1,4,7,11,15],[2,5,8,12,19],[3,6,9,16,22],[10,13,14,17,24],[18,21,23,26,30]]`,
#   `target = 5`
# - Output: `true`
#
# **Example 2**
# - Input:
#   `matrix = [[1,4,7,11,15],[2,5,8,12,19],[3,6,9,16,22],[10,13,14,17,24],[18,21,23,26,30]]`,
#   `target = 20`
# - Output: `false`
#
# ## Constraints
# - `m == matrix.length`
# - `n == matrix[i].length`
# - `1 ≤ m, n ≤ 300`
# - `-10^9 ≤ matrix[i][j] ≤ 10^9`
# - Each row is sorted in ascending order
# - Each column is sorted in ascending order
# - `-10^9 ≤ target ≤ 10^9`

# %% [markdown]
# # 1201. Ugly Number III
#
# ## Difficulty
# Medium
#
# ## Description
# An ugly number is a positive integer that is divisible by `a`, `b`, or `c`.
#
# Given four integers `n`, `a`, `b`, and `c`, return the `n`th ugly number.
#
# ## Examples
#
# **Example 1**
# - Input: `n = 3`, `a = 2`, `b = 3`, `c = 5`
# - Output: `4`
# - Explanation: The ugly numbers are `2, 3, 4, 5, 6, 8, 9, 10, ...`. The 3rd is 4.
#
# **Example 2**
# - Input: `n = 4`, `a = 2`, `b = 3`, `c = 4`
# - Output: `6`
# - Explanation: The ugly numbers are `2, 3, 4, 6, 8, 9, 10, 12, ...`. The 4th is 6.
#
# **Example 3**
# - Input: `n = 5`, `a = 2`, `b = 11`, `c = 13`
# - Output: `10`
# - Explanation: The ugly numbers are `2, 4, 6, 8, 10, 11, 12, 13, ...`. The 5th is 10.
#
# ## Constraints
# - `1 ≤ n, a, b, c ≤ 10^9`
# - `1 ≤ a × b × c ≤ 10^18`
# - The result is guaranteed to be in the range `[1, 2 × 10^9]`

# %% [markdown]
# # 719. Find K-th Smallest Pair Distance
#
# ## Difficulty
# Hard
#
# ## Description
# The distance of a pair of integers `a` and `b` is defined as the absolute difference between `a` and `b`.
#
# Given an integer array `nums` and an integer `k`, return the `k`th smallest distance among all pairs `(nums[i], nums[j])` where `0 ≤ i < j < nums.length`.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,3,1]`, `k = 1`
# - Output: `0`
# - Explanation:
#   Pairs and distances:
#   `(1,3) → 2`, `(1,1) → 0`, `(3,1) → 2`
#   The 1st smallest distance is 0.
#
# **Example 2**
# - Input: `nums = [1,1,1]`, `k = 2`
# - Output: `0`
#
# **Example 3**
# - Input: `nums = [1,6,1]`, `k = 3`
# - Output: `5`
#
# ## Constraints
# - `n == nums.length`
# - `2 ≤ n ≤ 10^4`
# - `0 ≤ nums[i] ≤ 10^6`
# - `1 ≤ k ≤ n × (n - 1) / 2`

# %% [markdown]
# # Sum of Manhattan Distances Between All Pairs of Points
#
# ## Difficulty
# Medium
#
# ## Description
# Given `n` integer coordinate points, find the sum of the Manhattan distances between all pairs of points.
#
# The Manhattan distance between two points `(x1, y1)` and `(x2, y2)` is defined as:
# `|x1 - x2| + |y1 - y2|`.
#
# ## Examples
#
# **Example 1**
# - Input:
#   `n = 4`
#   `p1 = (-1, 5)`, `p2 = (1, 6)`, `p3 = (3, 5)`, `p4 = (2, 3)`
# - Output: `22`
# - Explanation:
#   Distances from `(-1, 5)` to `(1, 6)`, `(3, 5)`, `(2, 3)` are `3`, `4`, `5` → sum = `12`
#   Distances from `(1, 6)` to `(3, 5)`, `(2, 3)` are `3`, `4` → sum = `19`
#   Distance from `(3, 5)` to `(2, 3)` is `3` → total sum = `22`
#
# ## Constraints
# - `1 ≤ n ≤ 10^5`
# - Coordinates are integers

# %% [markdown]
# # Count Inversions
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array of integers `arr[]`, find the inversion count of the array.
#
# An inversion is a pair of indices `(i, j)` such that `i < j` and `arr[i] > arr[j]`.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = [2, 4, 1, 3, 5]`
# - Output: `3`
# - Explanation: The inversions are `(2,1)`, `(4,1)`, `(4,3)`.
#
# **Example 2**
# - Input: `arr[] = [2, 3, 4, 5, 6]`
# - Output: `0`
# - Explanation: The array is already sorted.
#
# **Example 3**
# - Input: `arr[] = [10, 10, 10]`
# - Output: `0`
# - Explanation: All elements are equal, so no inversions exist.
#
# ## Constraints
# - `1 ≤ arr.size() ≤ 10^5`
# - `1 ≤ arr[i] ≤ 10^4`

# %% [markdown]
# # Segregate Even and Odd Numbers
#
# ## Difficulty
# Basic
#
# ## Description
# Given an array `arr`, segregate even and odd numbers such that all even numbers appear first in sorted order, followed by all odd numbers in sorted order.
#
# The array must be modified **in-place**.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = [12, 34, 45, 9, 8, 90, 3]`
# - Output: `[8, 12, 34, 90, 3, 9, 45]`
# - Explanation: Even numbers are `12, 34, 8, 90` and odd numbers are `45, 9, 3`.
#
# **Example 2**
# - Input: `arr[] = [0, 1, 2, 3, 4]`
# - Output: `[0, 2, 4, 1, 3]`
# - Explanation: Even numbers are `0, 2, 4` and odd numbers are `1, 3`.
#
# **Example 3**
# - Input: `arr[] = [10, 22, 4, 6]`
# - Output: `[10, 22, 4, 6]`
# - Explanation: All elements are even, so no segregation is needed.
#
# ## Constraints
# - `1 ≤ arr.size() ≤ 10^6`
# - `0 ≤ arr[i] ≤ 10^5`

# %% [markdown]
# # 31. Next Permutation
#
# ## Difficulty
# Medium
#
# ## Description
# A permutation of an array of integers is an arrangement of its elements into a sequence.
#
# The next permutation of an array is the next lexicographically greater permutation. If no such permutation exists, the array should be rearranged into the lowest possible order (i.e., sorted in ascending order).
#
# Given an array of integers `nums`, find the next permutation of `nums`.
#
# The replacement must be done **in place** and use **constant extra memory**.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [1,2,3]`
# - Output: `[1,3,2]`
#
# **Example 2**
# - Input: `nums = [3,2,1]`
# - Output: `[1,2,3]`
#
# **Example 3**
# - Input: `nums = [1,1,5]`
# - Output: `[1,5,1]`
#
# ## Constraints
# - `1 ≤ nums.length ≤ 100`
# - `0 ≤ nums[i] ≤ 100`

# %% [markdown]
# # Sorting Elements of an Array by Frequency
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array `A[]` of integers, sort the array according to the frequency of elements.
#
# - Elements with **higher frequency** should appear first.
# - If two elements have the **same frequency**, the **smaller number** should come first.
#
# ## Examples
#
# **Example 1**
# - Input: `A = [5, 5, 4, 6, 4]`
# - Output: `4 4 5 5 6`
# - Explanation:
#   Both 4 and 5 appear twice. Since frequencies are equal, the smaller number (4) comes first.
#   Element 6 appears once, so it comes last.
#
# **Example 2**
# - Input: `A = [9, 9, 9, 2, 5]`
# - Output: `9 9 9 2 5`
# - Explanation:
#   Element 9 appears three times, which is the highest frequency.
#   Elements 2 and 5 appear once, and since frequencies are equal, 2 comes before 5.
#
# ## Constraints
# - `1 ≤ T ≤ 70`
# - `1 ≤ N ≤ 130`
# - `1 ≤ A[i] ≤ 60`

# %% [markdown]
# # 668. Kth Smallest Number in Multiplication Table
#
# ## Difficulty
# Hard
#
# ## Description
# The multiplication table of size `m x n` is an integer matrix where each element is defined as
# `mat[i][j] = i × j` (1-indexed).
#
# Given three integers `m`, `n`, and `k`, return the `k`th smallest element in the `m x n` multiplication table.
#
# ## Examples
#
# **Example 1**
# - Input: `m = 3`, `n = 3`, `k = 5`
# - Output: `3`
# - Explanation: The 5th smallest number in the multiplication table is 3.
#
# **Example 2**
# - Input: `m = 2`, `n = 3`, `k = 6`
# - Output: `6`
# - Explanation: The 6th smallest number in the multiplication table is 6.
#
# ## Constraints
# - `1 ≤ m, n ≤ 3 × 10^4`
# - `1 ≤ k ≤ m × n`

# %% [markdown]
# # Allocate Minimum Pages
#
# ## Difficulty
# Medium
#
# ## Description
# Given an array `arr[]` where each element represents the number of pages in a book, and an integer `k` representing the number of students, allocate books to students such that:
#
# - Each student receives at least one book.
# - Each student is assigned a contiguous sequence of books.
# - No book is assigned to more than one student.
#
# The goal is to minimize the maximum number of pages assigned to any student.
# If it is not possible to allocate books to all students, return `-1`.
#
# ## Examples
#
# **Example 1**
# - Input: `arr[] = [12, 34, 67, 90]`, `k = 2`
# - Output: `113`
# - Explanation:
#   Possible allocations:
#   - `[12]` and `[34, 67, 90]` → max pages = 191
#   - `[12, 34]` and `[67, 90]` → max pages = 157
#   - `[12, 34, 67]` and `[90]` → max pages = 113
#   The minimum possible maximum is 113.
#
# **Example 2**
# - Input: `arr[] = [15, 17, 20]`, `k = 5`
# - Output: `-1`
# - Explanation: There are more students than books, so allocation is not possible.
#
# ## Constraints
# - `1 ≤ arr.size() ≤ 10^6`
# - `1 ≤ arr[i], k ≤ 10^3`

# %% [markdown]
# # 878. Nth Magical Number
#
# ## Difficulty
# Hard
#
# ## Description
# A positive integer is considered **magical** if it is divisible by either `a` or `b`.
#
# Given three integers `n`, `a`, and `b`, return the `n`th magical number.
# Since the result can be very large, return it modulo `10^9 + 7`.
#
# ## Examples
#
# **Example 1**
# - Input: `n = 1`, `a = 2`, `b = 3`
# - Output: `2`
#
# **Example 2**
# - Input: `n = 4`, `a = 2`, `b = 3`
# - Output: `6`
#
# ## Constraints
# - `1 ≤ n ≤ 10^9`
# - `2 ≤ a, b ≤ 4 × 10^4`

# %% [markdown]
# # 315. Count of Smaller Numbers After Self
#
# ## Difficulty
# Hard
#
# ## Description
# Given an integer array `nums`, return an integer array `counts` where `counts[i]` represents the number of elements smaller than `nums[i]` that appear to the right of index `i`.
#
# ## Examples
#
# **Example 1**
# - Input: `nums = [5,2,6,1]`
# - Output: `[2,1,1,0]`
# - Explanation:
#   - To the right of `5`, there are `2` smaller elements (`2` and `1`)
#   - To the right of `2`, there is `1` smaller element (`1`)
#   - To the right of `6`, there is `1` smaller element (`1`)
#   - To the right of `1`, there are `0` smaller elements
#
# **Example 2**
# - Input: `nums = [-1]`
# - Output: `[0]`
#
# **Example 3**
# - Input: `nums = [-1, -1]`
# - Output: `[0, 0]`
#
# ## Constraints
# - `1 ≤ nums.length ≤ 10^5`
# - `-10^4 ≤ nums[i] ≤ 10^4`
